# %%
# Import Global Dependencies
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms
import torch.optim as optim
import torch.nn as nn
import torch
import torch.nn.functional as F
# Import Helper Libaries
import matplotlib.pyplot as plt
from torchinfo import summary
import numpy as np
import random
import copy

device = ('cuda' if torch.cuda.is_available() else 'cpu')

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# %% [markdown]
# #### CNN Definition

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        # First convolutional layer
        self.conv1 = nn.Conv2d(1, 32, kernel_size=5)
        # Second convolutional layer
        self.conv2 = nn.Conv2d(32, 64, kernel_size=5)
        # Max pooling layer
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        # Fully connected layer
        self.fc1 = nn.Linear(64 * 4 * 4, 512)
        # Output layer
        self.fc2 = nn.Linear(512, 10)

    def forward(self, x):
        # Convolutional layer 1 with ReLU activation and max pooling
        x = self.pool(F.relu(self.conv1(x)))
        # Convolutional layer 2 with ReLU activation and max pooling
        x = self.pool(F.relu(self.conv2(x)))
        # Flatten the output for the fully connected layer
        x = x.view(-1, 64 * 4 * 4)
        # Fully connected layer with ReLU activation
        x = F.relu(self.fc1(x))
        # Output layer with softmax activation
        x = F.softmax(self.fc2(x), dim=1)
        return x

# %%
def client_update(client_model, optimizer, train_loader, epochs):
    model.train()
    
    for i in range(epochs):
        for batch_index, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = client_model(data)
            loss = F.cross_entropy(output, target)
            loss.backward()
            optimizer.step()
    return loss.item()

# %%
def server_average(global_model, client_models):
    global_dict = global_model.state_dict()
    for k in global_dict.keys():
         global_dict[k] = torch.stack([client_models[i].state_dict()[k] for i in range(len(client_models))], 0).mean(0)
            
    global_model.load_state_dict(global_dict)
    
    for model in client_models:
        model.load_state_dict(global_model.state_dict())

# %%
def test(global_model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = global_model(data)
            test_loss += F.cross_entropy(output, target, reduction='sum').item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    acc = correct / len(test_loader.dataset)

    return test_loss, acc

# %%
# NON-IID case: every client has images of two categories chosen from [0, 1], [2, 3], [4, 5], [6, 7], or [8, 9].

# Hyperparameters

num_clients = 100
num_selected = 10
num_rounds = 1200
epochs = 5
batch_size = 10

# Creating decentralized datasets

traindata = datasets.MNIST('./data', train=True, download=True, transform=transform)
target_labels = torch.stack([traindata.targets == i for i in range(10)])
target_labels_split = []
for i in range(5):
    target_labels_split += torch.split(torch.where(target_labels[(2 * i):(2 * (i + 1))].sum(0))[0], int(60000 / num_clients))
    
traindata_split = [torch.utils.data.Subset(traindata, tl) for tl in target_labels_split]
train_loader = [torch.utils.data.DataLoader(x, batch_size=batch_size, shuffle=True) for x in traindata_split]

test_loader = torch.utils.data.DataLoader(
        datasets.MNIST('./data', train=False, transform=transform), batch_size=batch_size, shuffle=True)


# Instantiate models and optimizers

global_model = CNN().to(device)
client_models = [CNN().to(device) for _ in range(num_selected)]
for model in client_models:
    model.load_state_dict(global_model.state_dict())

opt = [optim.SGD(model.parameters(), lr=0.1) for model in client_models]

# Runnining FL
nonIID_accuracy_list = []
nonIID_avg_training_losses = []
nonIID_eval_losses = []
for r in range(num_rounds):
    # select random clients
    client_idx = np.random.permutation(num_clients)[:num_selected]

    # client update
    loss = 0
    for i in range(num_selected):
        loss += client_update(client_models[i], opt[i], train_loader[client_idx[i]], epochs=epochs)
    
    # serer aggregate
    server_average(global_model, client_models)
    test_loss, acc = test(global_model, test_loader)
    nonIID_accuracy_list.append(acc)
    nonIID_eval_losses.append(test_loss)
    avg_training_loss = loss/ num_selected
    nonIID_avg_training_losses.append(avg_training_loss)
    if(r % 10 == 0):
        print('%d-th round' % r)
        print('average train loss %0.3g | test loss %0.3g | test acc: %0.3f' % (loss / num_selected, test_loss, acc))
        
torch.save(global_model,'nonIID_Model')
NONIID_MODEL = torch.load('nonIID_Model')
NONIID_SUMMARY= summary(NONIID_MODEL, (1, 28, 28),verbose=2, col_width=16, col_names=["kernel_size", "output_size", "num_params", "mult_adds"], row_settings=["var_names"])

import matplotlib.pyplot as plt
print(nonIID_accuracy_list)
# Plotting accuracy
plt.figure(figsize=(12, 6))
plt.plot(range(num_rounds), nonIID_accuracy_list, label='Accuracy')
plt.xlabel('Number of Rounds')
plt.ylabel('Accuracy')
plt.title('Accuracy over Rounds')
plt.legend()
plt.ylim(0.98, 1.0)  # Set y-axis limits
plt.grid(True)
plt.show()
# Out:
# 0-th round
# average train loss 1.47 | test loss 2.21 | test acc: 0.265
# 10-th round
# average train loss 1.46 | test loss 1.79 | test acc: 0.717
# 20-th round
# average train loss 1.47 | test loss 1.6 | test acc: 0.891
# 30-th round
# average train loss 1.46 | test loss 1.63 | test acc: 0.838
# 40-th round
# average train loss 1.46 | test loss 1.55 | test acc: 0.933
# 50-th round
# average train loss 1.46 | test loss 1.58 | test acc: 0.896
# 60-th round
# average train loss 1.46 | test loss 1.54 | test acc: 0.933
# 70-th round
# average train loss 1.47 | test loss 1.53 | test acc: 0.938
# 80-th round
# average train loss 1.46 | test loss 1.56 | test acc: 0.912
# 90-th round
# average train loss 1.46 | test loss 1.51 | test acc: 0.960
# 100-th round
# average train loss 1.46 | test loss 1.51 | test acc: 0.953
# 110-th round
# average train loss 1.46 | test loss 1.53 | test acc: 0.943
# 120-th round
# average train loss 1.46 | test loss 1.51 | test acc: 0.958
# 130-th round
# average train loss 1.46 | test loss 1.52 | test acc: 0.943
# 140-th round
# average train loss 1.47 | test loss 1.55 | test acc: 0.926
# 150-th round
# average train loss 1.46 | test loss 1.5 | test acc: 0.965
# 160-th round
# average train loss 1.46 | test loss 1.5 | test acc: 0.968
# 170-th round
# average train loss 1.46 | test loss 1.49 | test acc: 0.973
# 180-th round
# average train loss 1.46 | test loss 1.5 | test acc: 0.964
# 190-th round
# average train loss 1.46 | test loss 1.5 | test acc: 0.970
# 200-th round
# average train loss 1.46 | test loss 1.49 | test acc: 0.979
# 210-th round
# average train loss 1.46 | test loss 1.49 | test acc: 0.973
# 220-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.980
# 230-th round
# average train loss 1.46 | test loss 1.51 | test acc: 0.957
# 240-th round
# average train loss 1.46 | test loss 1.49 | test acc: 0.971
# 250-th round
# average train loss 1.46 | test loss 1.49 | test acc: 0.976
# 260-th round
# average train loss 1.46 | test loss 1.5 | test acc: 0.968
# 270-th round
# average train loss 1.46 | test loss 1.5 | test acc: 0.967
# 280-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.984
# 290-th round
# average train loss 1.46 | test loss 1.54 | test acc: 0.930
# 300-th round
# average train loss 1.46 | test loss 1.5 | test acc: 0.961
# 310-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.979
# 320-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.984
# 330-th round
# average train loss 1.46 | test loss 1.49 | test acc: 0.973
# 340-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.984
# 350-th round
# average train loss 1.46 | test loss 1.5 | test acc: 0.964
# 360-th round
# average train loss 1.46 | test loss 1.49 | test acc: 0.978
# 370-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.978
# 380-th round
# average train loss 1.46 | test loss 1.5 | test acc: 0.967
# 390-th round
# average train loss 1.46 | test loss 1.49 | test acc: 0.977
# 400-th round
# average train loss 1.46 | test loss 1.5 | test acc: 0.967
# 410-th round
# average train loss 1.46 | test loss 1.49 | test acc: 0.976
# 420-th round
# average train loss 1.46 | test loss 1.49 | test acc: 0.973
# 430-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.984
# 440-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.981
# 450-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.982
# 460-th round
# average train loss 1.46 | test loss 1.51 | test acc: 0.955
# 470-th round
# average train loss 1.46 | test loss 1.49 | test acc: 0.979
# 480-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.983
# 490-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.980
# 500-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.979
# 510-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.987
# 520-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.985
# 530-th round
# average train loss 1.47 | test loss 1.48 | test acc: 0.986
# 540-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.982
# 550-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.982
# 560-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.988
# 570-th round
# average train loss 1.46 | test loss 1.49 | test acc: 0.971
# 580-th round
# average train loss 1.46 | test loss 1.49 | test acc: 0.971
# 590-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.986
# 600-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.979
# 610-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.987
# 620-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.980
# 630-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.985
# 640-th round
# average train loss 1.46 | test loss 1.49 | test acc: 0.973
# 650-th round
# average train loss 1.46 | test loss 1.49 | test acc: 0.972
# 660-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.984
# 670-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.984
# 680-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.986
# 690-th round
# average train loss 1.46 | test loss 1.47 | test acc: 0.988
# 700-th round
# average train loss 1.46 | test loss 1.47 | test acc: 0.988
# 710-th round
# average train loss 1.46 | test loss 1.47 | test acc: 0.987
# 720-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.987
# 730-th round
# average train loss 1.46 | test loss 1.47 | test acc: 0.990
# 740-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.983
# 750-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.983
# 760-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.978
# 770-th round
# average train loss 1.46 | test loss 1.47 | test acc: 0.988
# 780-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.985
# 790-th round
# average train loss 1.46 | test loss 1.47 | test acc: 0.989
# 800-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.987
# 810-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.987
# 820-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.986
# 830-th round
# average train loss 1.46 | test loss 1.47 | test acc: 0.988
# 840-th round
# average train loss 1.46 | test loss 1.47 | test acc: 0.989
# 850-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.986
# 860-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.987
# 870-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.987
# 880-th round
# average train loss 1.46 | test loss 1.47 | test acc: 0.989
# 890-th round
# average train loss 1.46 | test loss 1.47 | test acc: 0.989
# 900-th round
# average train loss 1.46 | test loss 1.47 | test acc: 0.989
# 910-th round
# average train loss 1.46 | test loss 1.47 | test acc: 0.990
# 920-th round
# average train loss 1.46 | test loss 1.49 | test acc: 0.973
# 930-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.985
# 940-th round
# average train loss 1.46 | test loss 1.47 | test acc: 0.989
# 950-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.982
# 960-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.980
# 970-th round
# average train loss 1.46 | test loss 1.52 | test acc: 0.947
# 980-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.986
# 990-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.984
# 1000-th round
# average train loss 1.46 | test loss 1.47 | test acc: 0.990
# 1010-th round
# average train loss 1.46 | test loss 1.47 | test acc: 0.990
# 1020-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.984
# 1030-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.985
# 1040-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.986
# 1050-th round
# average train loss 1.46 | test loss 1.47 | test acc: 0.990
# 1060-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.978
# 1070-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.982
# 1080-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.985
# 1090-th round
# average train loss 1.46 | test loss 1.47 | test acc: 0.990
# 1100-th round
# average train loss 1.46 | test loss 1.47 | test acc: 0.991
# 1110-th round
# average train loss 1.46 | test loss 1.47 | test acc: 0.989
# 1120-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.986
# 1130-th round
# average train loss 1.46 | test loss 1.47 | test acc: 0.988
# 1140-th round
# average train loss 1.46 | test loss 1.47 | test acc: 0.991
# 1150-th round
# average train loss 1.46 | test loss 1.48 | test acc: 0.986
# 1160-th round
# average train loss 1.46 | test loss 1.47 | test acc: 0.988
# 1170-th round
# average train loss 1.46 | test loss 1.47 | test acc: 0.992
# 1180-th round
# average train loss 1.47 | test loss 1.47 | test acc: 0.991
# 1190-th round
# average train loss 1.46 | test loss 1.47 | test acc: 0.991
# ========================================================================================================
# Layer (type (var_name))                  Kernel Shape     Output Shape     Param #          Mult-Adds
# ========================================================================================================
# CNN (CNN)                                --               [1, 10]          --               --
# ├─Conv2d (conv1)                         [5, 5]           [32, 24, 24]     832              638,976
# │    └─weight                            [1, 32, 5, 5]                     ├─800
# │    └─bias                              [32]                              └─32
# ├─MaxPool2d (pool)                       2                [32, 12, 12]     --               --
# ├─Conv2d (conv2)                         [5, 5]           [64, 8, 8]       51,264           26,247,168
# │    └─weight                            [32, 64, 5, 5]                    ├─51,200
# │    └─bias                              [64]                              └─64
# ├─MaxPool2d (pool)                       2                [64, 4, 4]       --               --
# ├─Linear (fc1)                           --               [1, 512]         524,800          524,800
# │    └─weight                            [1024, 512]                       ├─524,288
# │    └─bias                              [512]                             └─512
# ├─Linear (fc2)                           --               [1, 10]          5,130            5,130
# │    └─weight                            [512, 10]                         ├─5,120
# │    └─bias                              [10]                              └─10
# ========================================================================================================
# Total params: 582,026
# Trainable params: 582,026
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 27.42
# ========================================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.18
# Params size (MB): 2.33
# Estimated Total Size (MB): 2.52
# ========================================================================================================
# [0.2652, 0.5041, 0.5286, 0.629, 0.6203, 0.4399, 0.4047, 0.6957, 0.7418, 0.5936, 0.7169, 0.6588, 0.7873, 0.7967, 0.8459, 0.8792, 0.811, 0.8681, 0.9047, 0.8886, 0.8912, 0.8574, 0.8391, 0.7998, 0.8872, 0.881, 0.8331, 0.9035, 0.8825, 0.9063, 0.8381, 0.8604, 0.824, 0.8464, 0.9124, 0.8954, 0.8971, 0.9087, 0.8214, 0.8905, 0.9335, 0.8574, 0.9481, 0.8609, 0.92, 0.9009, 0.9, 0.8486, 0.